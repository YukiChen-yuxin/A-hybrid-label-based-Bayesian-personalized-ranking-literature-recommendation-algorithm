# %%
import pandas as pd

# %%
data=pd.read_csv("E:\\2020 慧源共享·数据悦读第二届高校开放数据创新研究大赛\\data\\数据\\下载行为日志\\下载行为日志.csv",error_bad_lines=False)
# Out:
# b'Skipping line 15073: expected 11 fields, saw 12\nSkipping line 15074: expected 11 fields, saw 12\nSkipping line 15075: expected 11 fields, saw 12\nSkipping line 15076: expected 11 fields, saw 12\nSkipping line 15077: expected 11 fields, saw 12\nSkipping line 15078: expected 11 fields, saw 12\nSkipping line 15079: expected 11 fields, saw 12\nSkipping line 15952: expected 11 fields, saw 12\nSkipping line 18119: expected 11 fields, saw 12\nSkipping line 18120: expected 11 fields, saw 12\nSkipping line 18169: expected 11 fields, saw 12\nSkipping line 19044: expected 11 fields, saw 12\nSkipping line 19447: expected 11 fields, saw 12\nSkipping line 21622: expected 11 fields, saw 12\nSkipping line 21623: expected 11 fields, saw 12\nSkipping line 21624: expected 11 fields, saw 12\nSkipping line 21625: expected 11 fields, saw 12\nSkipping line 21626: expected 11 fields, saw 12\nSkipping line 29731: expected 11 fields, saw 12\nSkipping line 30371: expected 11 fields, saw 12\nSkipping line 30
# ...

# %%
data.head()
# Out:
#   article_id           user_id user_type                 date_time  \
# 0     133918  6ebbb7f0602fd678     group  2019-12-08T10:42:12.769Z
# 1     143456  6931fa1df50eda83     group  2019-12-19T13:54:46.955Z
# 2      16974  8fe0fb76e0dcc243     group  2019-12-31T06:12:35.529Z
# 3     191501  a1b520cbe41f9397     group  2019-12-06T09:34:38.554Z
# 4     203663  6a56a4c1edfd60c8     group  2019-12-24T00:20:29.594Z
#
#          article_title                  keywords         author  \
# 0  辐射图像法测量火焰断面温度场的实验研究        红外成像;红外辐射;火焰断面;温度场  薛飞;马增益;李晓东;王飞
# 1  污水处理用活性炭流化床再生影响因素研究                活性炭;流化床;再生        刘守新;张世润
# 2      热轧带钢边部加热器系统及其控制  边部加热器;感应加热;逆变器;热轧带钢;控制系统          叶茂;刘明
# 3      头部MRA图像的血管自动追踪法   离散型傅氏变换;自校正算法;误差修正;阻抗测量       张善俊;田中雅彦
# 4   绿色高性能混凝土--混凝土的发展方向               绿色高性能混凝土;环保            吴中伟
#
#                    unit type province           classcode
# 0             大学热能工程研究所    1      辽宁省  O643.21;TK16;TP274
# 1  东北林业大学(哈尔滨);ls东北林业大学    1      山东省             TQ424.1
# ...

# %%
data_download_per=data[data['user_type']=='person']

# %%
outputpath='E:\\2020 慧源共享·数据悦读第二届高校开放数据创新研究大赛\\data\\数据\\下载行为日志_个人用户.csv'
data_download_per.to_csv(outputpath,sep=',',index=False,header=True)

# %%
data_download_per=pd.read_csv("E:\\2020 慧源共享·数据悦读第二届高校开放数据创新研究大赛\\data\\数据\\下载行为日志_个人用户.csv",error_bad_lines=False)

# %%
data_download_per.head()
# Out:
#   article_id           user_id user_type                 date_time  \
# 0    6769978  9fbc355f2519fc63    person  2019-12-29T10:50:27.727Z
# 1    7427381  ebb77885bf041c50    person  2019-12-25T05:08:56.686Z
# 2    7461623  86d5f40d3be7d711    person  2019-12-17T08:41:26.733Z
# 3    8443319  7dec20b3e3230936    person  2019-12-26T09:02:42.437Z
# 4    8443319  7dec20b3e3230936    person  2019-12-26T09:02:43.346Z
#
#                  article_title                                  keywords  \
# 0  加强大遗址保护,构建城乡一体化生态良好的山水园林新格局  生态环境;遗址保护;城乡一体化;山水园林;城市规划;山水景观;山水格局;水系景观
# 1       基于单片机的太阳光伏发电系统逆变器的仿真设计                         逆变器;光伏;单片机;脉冲宽度调制
# 2                浅谈医院中药饮片的质量管理                             中药饮片;质量管理;安全性
# 3              土壤中微生物与锶的吸附行为研究                         土壤环境;微生物;锶元素;吸附行为
# 4              土壤中微生物与锶的吸附行为研究                         土壤环境;微生物;锶元素;吸附行为
#
#                 author                                               unit  \
# ...

# %%
data_dow_per=data_download_per.drop(columns=['user_type','date_time','unit','province','author'])

# %%
data_dow_per.head()
# Out:
#     article_id           user_id                article_title  \
# 151    6769978  9fbc355f2519fc63  加强大遗址保护,构建城乡一体化生态良好的山水园林新格局
# 312    7427381  ebb77885bf041c50       基于单片机的太阳光伏发电系统逆变器的仿真设计
# 320    7461623  86d5f40d3be7d711                浅谈医院中药饮片的质量管理
# 531    8443319  7dec20b3e3230936              土壤中微生物与锶的吸附行为研究
# 532    8443319  7dec20b3e3230936              土壤中微生物与锶的吸附行为研究
#
#                                      keywords type      classcode
# 151  生态环境;遗址保护;城乡一体化;山水园林;城市规划;山水景观;山水格局;水系景观    1       TU986.43
# 312                         逆变器;光伏;单片机;脉冲宽度调制    1  TM464;TP368.1
# 320                             中药饮片;质量管理;安全性    1           R288
# 531                         土壤环境;微生物;锶元素;吸附行为    1         S151.9
# 532                         土壤环境;微生物;锶元素;吸附行为    1         S151.9

# %%
data_dow_per.index=range(1,len(data_dow_per)+1)

# %%
data_dow_per.head()
# Out:
#   article_id           user_id                article_title  \
# 1    6769978  9fbc355f2519fc63  加强大遗址保护,构建城乡一体化生态良好的山水园林新格局
# 2    7427381  ebb77885bf041c50       基于单片机的太阳光伏发电系统逆变器的仿真设计
# 3    7461623  86d5f40d3be7d711                浅谈医院中药饮片的质量管理
# 4    8443319  7dec20b3e3230936              土壤中微生物与锶的吸附行为研究
# 5    8443319  7dec20b3e3230936              土壤中微生物与锶的吸附行为研究
#
#                                    keywords type      classcode
# 1  生态环境;遗址保护;城乡一体化;山水园林;城市规划;山水景观;山水格局;水系景观    1       TU986.43
# 2                         逆变器;光伏;单片机;脉冲宽度调制    1  TM464;TP368.1
# 3                             中药饮片;质量管理;安全性    1           R288
# 4                         土壤环境;微生物;锶元素;吸附行为    1         S151.9
# 5                         土壤环境;微生物;锶元素;吸附行为    1         S151.9

# %%
data2=pd.read_csv("E:\\2020 慧源共享·数据悦读第二届高校开放数据创新研究大赛\\data\\数据\\检索行为日志.csv",error_bad_lines=False)
# Out:
# b'Skipping line 16248: expected 5 fields, saw 7\nSkipping line 18014: expected 5 fields, saw 7\nSkipping line 18055: expected 5 fields, saw 7\nSkipping line 18725: expected 5 fields, saw 7\nSkipping line 21164: expected 5 fields, saw 7\nSkipping line 23078: expected 5 fields, saw 7\nSkipping line 23330: expected 5 fields, saw 7\nSkipping line 23456: expected 5 fields, saw 7\nSkipping line 30328: expected 5 fields, saw 6\nSkipping line 85545: expected 5 fields, saw 6\nSkipping line 91256: expected 5 fields, saw 6\nSkipping line 107077: expected 5 fields, saw 8\n'
# ...

# %%
data2.head()
# Out:
#             user_id user_type              search_word  \
# 0  6ec4f0cc9160e0d9     group  护理本科生共情培训效果及对其临床沟通能力的影响
# 1  6ec4f0cc9160e0d9     group  护理本科生共情培训效果及对其临床沟通能力的影响
# 2  6ec4f0cc9160e0d9     group  护理本科生共情培训效果及对其临床沟通能力的影响
# 3  de40b5bbba2c300f     group  题名:(\高性能大功率高压电源技术研究\")"
# 4  6ec4f0cc9160e0d9     group  护理本科生共情培训效果及对其临床沟通能力的影响
#
#                   date_time province
# 0  2020-01-27T16:00:00.300Z      四川省
# 1  2020-01-27T16:00:00.892Z      四川省
# 2  2020-01-27T16:00:01.224Z      四川省
# 3  2020-01-27T16:00:01.618Z       上海
# 4  2020-01-27T16:00:02.581Z      四川省

# %%
data_search_per=data2[data2['user_type']=='person']

# %%
data_search_per.head()
outputpath='E:\\2020 慧源共享·数据悦读第二届高校开放数据创新研究大赛\\data\\数据\\检索行为日志_个人用户.csv'
data_search_per.to_csv(outputpath,sep=',',index=False,header=True)

# %%
data_search_per=pd.read_csv("E:\\2020 慧源共享·数据悦读第二届高校开放数据创新研究大赛\\data\\数据\\检索行为日志_个人用户.csv",error_bad_lines=False)

# %%
data_search_per.head()
# Out:
#             user_id user_type search_word                 date_time province
# 0  6b2d7c12399b477b    person      刹车水冷系统  2020-01-27T16:00:13.711Z      陕西省
# 1  8a8a1e5cf77ff4de    person    小学英语家庭作业  2020-01-27T16:00:17.184Z      山东省
# 2  8a8a1e5cf77ff4de    person    小学英语家庭作业  2020-01-27T16:00:29.715Z      山东省
# 3  8a8a1e5cf77ff4de    person    小学英语家庭作业  2020-01-27T16:00:56.312Z      山东省
# 4  7287e39b436c1e62    person        机票数据  2020-01-27T16:00:57.955Z      广东省

# %%
data_sea_per=data_search_per.drop(columns=['user_type','date_time','province'])

# %%
data_sea_per.index=range(1,len(data_sea_per)+1)
data_sea_per.head()
# Out:
#             user_id search_word
# 1  6b2d7c12399b477b      刹车水冷系统
# 2  8a8a1e5cf77ff4de    小学英语家庭作业
# 3  8a8a1e5cf77ff4de    小学英语家庭作业
# 4  8a8a1e5cf77ff4de    小学英语家庭作业
# 5  7287e39b436c1e62        机票数据

# %%
data3=pd.read_csv("E:\\2020 慧源共享·数据悦读第二届高校开放数据创新研究大赛\\data\\数据\\\浏览行为日志.csv",error_bad_lines=False)
# Out:
# b'Skipping line 2882: expected 11 fields, saw 12\nSkipping line 45529: expected 11 fields, saw 12\nSkipping line 46162: expected 11 fields, saw 12\nSkipping line 48280: expected 11 fields, saw 12\n'
# b'Skipping line 122565: expected 11 fields, saw 13\nSkipping line 122821: expected 11 fields, saw 12\n'
# b'Skipping line 140689: expected 11 fields, saw 12\nSkipping line 164989: expected 11 fields, saw 12\nSkipping line 167816: expected 11 fields, saw 12\nSkipping line 167817: expected 11 fields, saw 12\nSkipping line 167870: expected 11 fields, saw 12\nSkipping line 175645: expected 11 fields, saw 12\nSkipping line 175822: expected 11 fields, saw 12\n'
# b'Skipping line 229804: expected 11 fields, saw 12\nSkipping line 237654: expected 11 fields, saw 12\nSkipping line 237655: expected 11 fields, saw 12\nSkipping line 237656: expected 11 fields, saw 12\nSkipping line 237657: expected 11 fields, saw 12\n'
# ...

# %%
data3.head()
# Out:
#                                      article_id           user_id user_type  \
# 0  +CyIV5gNyPun9oocfKyVttSvy+dQ1An5Kw2iV2hJ4i0=  e809b49b32ae2c96     group
# 1                              0120180802251631  16345fa16d3db8c3     group
# 2                              0120180802785721  27ee2323799c13d4     group
# 3                              0120180802832339  831e27564842540e     group
# 4                              0120180802832339  831e27564842540e     group
#
#                   date_time             article_title  \
# 0  2020-01-05T15:42:57.453Z                       NaN
# 1  2020-01-09T06:58:20.228Z               蓝牙节能喷涂机器人设计
# 2  2020-01-06T07:42:32.471Z  中宇银太陨石鉴定有限责任公司:专业性陨石鉴定机构
# 3  2020-01-17T02:58:15.229Z           正德：溜出官门去打仗的另类帝王
# 4  2020-01-17T02:57:06.094Z           正德：溜出官门去打仗的另类帝王
#
#                                             keywords  \
# 0  Chemical Explosives;Detonations;PETN;TATB;TNT;...
# 1                         六自由度;结合电控技术的混气喷枪;无线通信;丝杠升降
# ...

# %%
data_see_per=data3[data3['user_type']=='person']

# %%
outputpath='E:\\2020 慧源共享·数据悦读第二届高校开放数据创新研究大赛\\data\\数据\\浏览行为日志_个人用户.csv'
data_see_per.to_csv(outputpath,sep=',',index=False,header=True)

# %%
data_see_per=pd.read_csv("E:\\2020 慧源共享·数据悦读第二届高校开放数据创新研究大赛\\data\\数据\\浏览行为日志_个人用户.csv",error_bad_lines=False)
# Out:
# C:\Users\yuki\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_see_per
# Out:
#               article_id           user_id user_type  \
# 0       0120180804676542  4130035b8a4b59c0    person
# 1       0120180804676542  4130035b8a4b59c0    person
# 2       0120180804985060  96758755a2c52217    person
# 3       0120180804985060  de46b376f881b6d5    person
# 4       0120180805054765  7b28bde83d4b7414    person
# ...                  ...               ...       ...
# 832953     zzgy201810001  1af81811f3fc4cf6    person
# 832954     zzjs201901022  93abfee3bc085cbf    person
# 832955    zzyfl200102021  c26a04c676555c87    person
# 832956   zzyzdh200203008  c9d2abe18e7d8f33    person
# 832957   zzyzdh200203008  c9d2abe18e7d8f33    person
#
#                        date_time                 article_title  \
# 0       2019-12-01T12:27:06.399Z  来自地方，到代表地方：全国人大常委会应适度引入地域代表制
# 1       2019-12-01T12:26:45.906Z  来自地方，到代表地方：全国人大常委会应适度引入地域代表制
# 2       2020-01-18T15:31:00.966Z                 容易与灰指甲混淆的指甲疾病
# 3       2019-12-26T02:09:46.690Z                 容易与灰指甲混淆的指甲疾病
# ...

# %%
data_s_per=data_see_per.drop(columns=['user_type','date_time','unit','province','author'])

# %%
data_s_per.index=range(1,len(data_s_per)+1)
data_s_per.head()
# Out:
#          article_id           user_id                 article_title  \
# 1  0120180804676542  4130035b8a4b59c0  来自地方，到代表地方：全国人大常委会应适度引入地域代表制
# 2  0120180804676542  4130035b8a4b59c0  来自地方，到代表地方：全国人大常委会应适度引入地域代表制
# 3  0120180804985060  96758755a2c52217                 容易与灰指甲混淆的指甲疾病
# 4  0120180804985060  de46b376f881b6d5                 容易与灰指甲混淆的指甲疾病
# 5  0120180805054765  7b28bde83d4b7414                 小班幼儿建构游戏的生长策略
#
#                                    keywords type classcode
# 1  全国人大常委会;代表制;人民代表大会;地域;工作制度;国家权力;立法工作;立法权    2      D622
# 2  全国人大常委会;代表制;人民代表大会;地域;工作制度;国家权力;立法工作;立法权    2      D622
# 3                指甲疾病;灰指甲;真菌感染性疾病;指甲颜色;主要表现    2   R758.72
# 4                指甲疾病;灰指甲;真菌感染性疾病;指甲颜色;主要表现    2   R758.72
# 5              小班幼儿;游戏;生长;动作表现;孩子;目的地;积木;教师    2      G610

# %%
data_download_per[data_download_per['user_id']=='7dec20b3e3230936']
# Out:
#   article_id           user_id user_type                 date_time  \
# 3    8443319  7dec20b3e3230936    person  2019-12-26T09:02:42.437Z
# 4    8443319  7dec20b3e3230936    person  2019-12-26T09:02:43.346Z
# 5    8443319  7dec20b3e3230936    person  2019-12-26T09:02:43.751Z
#
#      article_title           keywords   author                       unit  \
# 3  土壤中微生物与锶的吸附行为研究  土壤环境;微生物;锶元素;吸附行为  赵雅平;张生栋  中国原子能科学研究院放射化学所,北京,201413
# 4  土壤中微生物与锶的吸附行为研究  土壤环境;微生物;锶元素;吸附行为  赵雅平;张生栋  中国原子能科学研究院放射化学所,北京,201413
# 5  土壤中微生物与锶的吸附行为研究  土壤环境;微生物;锶元素;吸附行为  赵雅平;张生栋  中国原子能科学研究院放射化学所,北京,201413
#
#    type province classcode
# 3   1.0       上海    S151.9
# 4   1.0       上海    S151.9
# 5   1.0       上海    S151.9

# %%
data_see_per[data_see_per['user_id']=='7dec20b3e3230936']
# Out:
#              article_id           user_id user_type                 date_time  \
# 286             8443319  7dec20b3e3230936    person  2019-12-26T09:02:35.694Z
# 33064  CN201510016700.4  7dec20b3e3230936    person  2019-12-26T09:04:50.841Z
# 33065  CN201510016700.4  7dec20b3e3230936    person  2019-12-26T09:29:31.728Z
#
#                  article_title           keywords   author  \
# 286            土壤中微生物与锶的吸附行为研究  土壤环境;微生物;锶元素;吸附行为  赵雅平;张生栋
# 33064  一种硫酸盐污染场地地下水污染治理和土壤修复方法                NaN      NaN
# 33065  一种硫酸盐污染场地地下水污染治理和土壤修复方法                NaN      NaN
#
#                             unit type province classcode
# 286    中国原子能科学研究院放射化学所,北京,201413    2        0    S151.9
# 33064                       同济大学    2        0       NaN
# 33065                       同济大学    2        0       NaN
